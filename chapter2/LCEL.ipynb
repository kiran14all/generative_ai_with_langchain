# %%
# setting the environment variables, the keys
import sys
import os

# The original attempt to add a parent directory to sys.path
# sys.path.insert(0, os.path.abspath('..'))

# The 'config' module was not found. Instead of importing from a missing config.py,
# you can set environment variables directly using os.environ. Replace 'YOUR_API_KEY_NAME'
# and 'YOUR_API_KEY_VALUE' with your actual environment variable names and keys.
# For sensitive information, consider using Colab's Secrets feature.

# Example:
# os.environ['OPENAI_API_KEY'] = 'YOUR_OPENAI_API_KEY'
# os.environ['GOOGLE_API_KEY'] = 'YOUR_GOOGLE_API_KEY'

# If you have specific keys, you can uncomment and fill them below:
# os.environ['KEY_NAME_1'] = 'KEY_VALUE_1'
# os.environ['KEY_NAME_2'] = 'KEY_VALUE_2'

# %%
# Load the OpenAI API key from Colab's secrets
from google.colab import userdata
import os

# Ensure 'OPENAI_API_KEY' is set in Colab's Secrets
try:
    os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
    print("OPENAI_API_KEY loaded successfully.")
except Exception as e:
    print(f"Error loading OPENAI_API_KEY from secrets: {e}")
    print("Please make sure your OpenAI API key is added to Colab Secrets with the name 'OPENAI_API_KEY'.")

# Ensure 'OPENAI_API_KEY' is set in Colab's Secrets
try:
    os.environ["GEMINI_API_KEY"] = userdata.get("GEMINI_API_KEY")
    print("GEMINI_API_KEY loaded successfully.")
except Exception as e:
    print(f"Error loading GEMINI_API_KEY from secrets: {e}")
    print("Please make sure your OpenAI API key is added to Colab Secrets with the name 'GEMINI_API_KEY'.")
# Out:
# OPENAI_API_KEY loaded successfully.
# GEMINI_API_KEY loaded successfully.

# %% [markdown]
# # LangChain Common Expression Language (LCEL)

# %%
# !pip uninstall -y langchain-openai langchain-core
# !pip install langchain-core==1.2.28
# Out:
# Found existing installation: langchain-openai 1.1.15
# Uninstalling langchain-openai-1.1.15:
#   Successfully uninstalled langchain-openai-1.1.15
# Found existing installation: langchain-core 1.3.0
# Uninstalling langchain-core-1.3.0:
#   Successfully uninstalled langchain-core-1.3.0
# ...
#   Using cached langchain_core-1.2.28-py3-none-any.whl.metadata (4.4 kB)
# ...
# Using cached langchain_core-1.2.28-py3-none-any.whl (508 kB)
# ...
#   Using cached langchain_openai-1.1.15-py3-none-any.whl.metadata (3.1 kB)
# ...
#   Using cached langchain_core-1.3.0-py3-none-any.whl.metadata (4.4 kB)
# ...
# Using cached langchain_openai-1.1.15-py3-none-any.whl (88 kB)
# Using cached langchain_core-1.3.0-py3-none-any.whl (515 kB)
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.28
#     Uninstalling langchain-core-1.2.28:
#       Successfully uninstalled langchain-core-1.2.28
# ...

# %%
# !pip install langchain-openai
# Out:
# ...
#   Using cached langchain_openai-1.1.15-py3-none-any.whl.metadata (3.1 kB)
# ...
#   Using cached langchain_core-1.3.0-py3-none-any.whl.metadata (4.4 kB)
# ...
# Using cached langchain_openai-1.1.15-py3-none-any.whl (88 kB)
# Using cached langchain_core-1.3.0-py3-none-any.whl (515 kB)
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.28
#     Uninstalling langchain-core-1.2.28:
#       Successfully uninstalled langchain-core-1.2.28
# ...

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI

# Create components
prompt = PromptTemplate.from_template("Tell me a joke about {topic}")
llm = ChatOpenAI()
output_parser = StrOutputParser()

# Chain them together using LCEL
chain = prompt | llm | output_parser

# Use the chain
result = chain.invoke({"topic": "programming"})
print(result)
# Out:
# Why was the JavaScript developer sad?
#
# Because he didn't know how to "null" his emotions.

# %% [markdown]
# # More complex expressions

# %%
# !pip install langchain_google_genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 2.5 MB/s eta 0:00:00
# ...

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI

chat = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# First chain generates a story
story_prompt = PromptTemplate.from_template("Write a short story about {topic}")
story_chain = story_prompt | chat | StrOutputParser()

# Second chain analyzes the story
analysis_prompt = PromptTemplate.from_template("Analyze the following story's mood:\n{story}")
analysis_chain = analysis_prompt | chat | StrOutputParser()

output_prompt = PromptTemplate.from_template(
    "Here's the story: \n{story}\n\nHere's the mood: \n{mood}"
)
# Combine chains
story_with_analysis = story_chain | analysis_chain

# Run the combined chain
result = story_with_analysis.invoke({"topic": "a rainy day"})
print(result)
# Out:
# The mood of the story is predominantly one of **tranquility, contemplative serenity, and peaceful acceptance**, with an underlying current of **cozy comfort**.
#
# Here's a breakdown of how this mood is established:
#
# 1.  **Tranquility and Stillness:**
#     *   **The Rain as a Catalyst:** The "relentless and steady" rain is not depicted as harsh or depressing, but rather as a force that "soften[s] the distant roar of traffic into a gentle hush" and imposes "its own agenda, a quiet, insistent decree to slow down." This immediately sets a quiet, unhurried pace.
#     *   **Blurred Edges:** The description of the rain "blurring the sharp edges of buildings" suggests a softening of reality, a less demanding, more fluid world.
#     *   **Clara's Surrender:** Her "sigh escaped... not of disappointment, but of surrender" explicitly states her acceptance of the stillness. She finds "a certain peace in the forced stillness, a liberation from the usual demands of a sunny day."
# ...

# %%
import google.generativeai as genai
import os
from google.colab import userdata

# Ensure GEMINI_API_KEY is set (should be from earlier cell)
if "GEMINI_API_KEY" not in os.environ:
    try:
        os.environ["GEMINI_API_KEY"] = userdata.get("GEMINI_API_KEY")
        print("GEMINI_API_KEY loaded successfully.")
    except Exception as e:
        print(f"Error loading GEMINI_API_KEY from secrets: {e}")
        print("Please make sure your GEMINI API key is added to Colab Secrets with the name 'GEMINI_API_KEY'.")

genai.configure(api_key=os.environ["GEMINI_API_KEY"])

print("Available Gemini models for 'generateContent':")
for m in genai.list_models():
    if "generateContent" in m.supported_generation_methods:
        print(m.name)
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)
# Available Gemini models for 'generateContent':
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# ...
